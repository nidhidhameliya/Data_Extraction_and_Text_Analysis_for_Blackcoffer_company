# %%
# Import necessary packages
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Nidhi
# [nltk_data]     Dhameliya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Nidhi
# [nltk_data]     Dhameliya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the directory where files will be saved
directory = 'C:/Users/Nidhi Dhameliya/Desktop/jupyter/Data_Extraction_and_Text_Analysis_for_Blackcoffer_company/TitleText/'

# Check if the directory exists, if not create it
if not os.path.exists(directory):
    os.makedirs(directory)

# Read the URL file into the pandas object
df = pd.read_excel('Input.xlsx')

# Loop through each row in the df
for index, row in df.iterrows():
    url = row['URL']
    url_id = row['URL_ID']

    # Make a request to the URL with timeout
    header = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"}
    try:
        response = requests.get(url, headers=header, timeout=10)
        if response.status_code != 200:
            print(f"Failed to retrieve {url_id} - Status code: {response.status_code}")
            continue
    except requests.exceptions.RequestException as e:
        print(f"Can't get response for {url_id}: {e}")
        continue

    # Create a BeautifulSoup object
    try:
        soup = BeautifulSoup(response.content, 'html.parser')
    except Exception as e:
        print(f"Can't parse page for {url_id}: {e}")
        continue

    # Find title
    try:
        title = soup.find('h1').get_text()
    except Exception as e:
        print(f"Can't get title for {url_id}: {e}")
        title = "No title found"

    # Find text
    article = ""
    try:
        for p in soup.find_all('p'):
            article += p.get_text()
    except Exception as e:
        print(f"Can't get text for {url_id}: {e}")

    # Define file name and write title and text to the file with UTF-8 encoding
    file_name = os.path.join(directory, f"{url_id}.txt")
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(title + '\n' + article)

    print(f"Successfully saved {url_id} content.")
# Out:
# Successfully saved Netclan20241017 content.
# Successfully saved Netclan20241018 content.
# Successfully saved Netclan20241019 content.
# Successfully saved Netclan20241020 content.
# Successfully saved Netclan20241021 content.
# Successfully saved Netclan20241022 content.
# Successfully saved Netclan20241023 content.
# Successfully saved Netclan20241024 content.
# Successfully saved Netclan20241025 content.
# Successfully saved Netclan20241026 content.
# Successfully saved Netclan20241027 content.
# Successfully saved Netclan20241028 content.
# Successfully saved Netclan20241029 content.
# Successfully saved Netclan20241030 content.
# Successfully saved Netclan20241031 content.
# Successfully saved Netclan20241032 content.
# Successfully saved Netclan20241033 content.
# Successfully saved Netclan20241034 content.
# Successfully saved Netclan20241035 content.
# Successfully saved Netclan20241036 content.
# Successfully saved Netclan20241037 content.
# Successfully saved Netclan20241038 content.
# Successfully saved Netclan20241039 content.
# Successfully saved Netclan20241040 content.
# Successfully saved Netclan20241041 content.
# Successfully saved Netclan20241042 content.
# Successfully saved Netclan20241043 content.
# Successfully saved Netclan20241044 content.
# Successfully saved Netclan20241045 content.
# Successfully saved Netclan20241046 content.
# Successfully saved Netclan20241047 content.
# Successfully saved Netclan20241048 content.
# Successfully saved Netclan20241049 content.
# Successfully saved Netclan20241050 content.
# Successfully saved Netclan20241051 content.
# Successfully saved Netclan20241052 content.
# Successfully saved Netclan20241053 content.
# Successfully saved Netclan20241054 content.
# Successfully saved Netclan20241055 content.
# Successfully saved Netclan20241056 content.
# Successfully saved Netclan20241057 content.
# Successfully saved Netclan20241058 content.
# Successfully saved Netclan20241059 content.
# Successfully saved Netclan20241060 content.
# Successfully saved Netclan20241061 content.
# Successfully saved Netclan20241062 content.
# Successfully saved Netclan20241063 content.
# Successfully saved Netclan20241064 content.
# Successfully saved Netclan20241065 content.
# Successfully saved Netclan20241066 content.
# Successfully saved Netclan20241067 content.
# Successfully saved Netclan20241068 content.
# Successfully saved Netclan20241069 content.
# Successfully saved Netclan20241070 content.
# Successfully saved Netclan20241071 content.
# Successfully saved Netclan20241072 content.
# Successfully saved Netclan20241073 content.
# Successfully saved Netclan20241074 content.
# Successfully saved Netclan20241075 content.
# Successfully saved Netclan20241076 content.
# Successfully saved Netclan20241077 content.
# Successfully saved Netclan20241078 content.
# Successfully saved Netclan20241079 content.
# Successfully saved Netclan20241080 content.
# Successfully saved Netclan20241081 content.
# Successfully saved Netclan20241082 content.
# Successfully saved Netclan20241083 content.
# Successfully saved Netclan20241084 content.
# Successfully saved Netclan20241085 content.
# Successfully saved Netclan20241086 content.
# Successfully saved Netclan20241087 content.
# Successfully saved Netclan20241088 content.
# Successfully saved Netclan20241089 content.
# Successfully saved Netclan20241090 content.
# Successfully saved Netclan20241091 content.
# Successfully saved Netclan20241092 content.
# Successfully saved Netclan20241093 content.
# Successfully saved Netclan20241094 content.
# Successfully saved Netclan20241095 content.
# Successfully saved Netclan20241096 content.
# Successfully saved Netclan20241097 content.
# Successfully saved Netclan20241098 content.
# Successfully saved Netclan20241099 content.
# Successfully saved Netclan20241100 content.
# Successfully saved Netclan20241101 content.
# Successfully saved Netclan20241102 content.
# Successfully saved Netclan20241103 content.
# Successfully saved Netclan20241104 content.
# Successfully saved Netclan20241105 content.
# Successfully saved Netclan20241106 content.
# Successfully saved Netclan20241107 content.
# Successfully saved Netclan20241108 content.
# Successfully saved Netclan20241109 content.
# Successfully saved Netclan20241110 content.
# Successfully saved Netclan20241111 content.
# Successfully saved Netclan20241112 content.
# Successfully saved Netclan20241113 content.
# Successfully saved Netclan20241114 content.
# Successfully saved Netclan20241115 content.
# Successfully saved Netclan20241116 content.
# Successfully saved Netclan20241117 content.
# Successfully saved Netclan20241118 content.
# Successfully saved Netclan20241119 content.
# Successfully saved Netclan20241120 content.
# Successfully saved Netclan20241121 content.
# Successfully saved Netclan20241122 content.
# Successfully saved Netclan20241123 content.
# Successfully saved Netclan20241124 content.
# Successfully saved Netclan20241125 content.
# Successfully saved Netclan20241126 content.
# Successfully saved Netclan20241127 content.
# Successfully saved Netclan20241128 content.
# Successfully saved Netclan20241129 content.
# Successfully saved Netclan20241130 content.
# Successfully saved Netclan20241131 content.
# Successfully saved Netclan20241132 content.
# Successfully saved Netclan20241133 content.
# Successfully saved Netclan20241134 content.
# Successfully saved Netclan20241135 content.
# Successfully saved Netclan20241136 content.
# Successfully saved Netclan20241137 content.
# Successfully saved Netclan20241138 content.
# Successfully saved Netclan20241139 content.
# Successfully saved Netclan20241140 content.
# Successfully saved Netclan20241141 content.
# Successfully saved Netclan20241142 content.
# Successfully saved Netclan20241143 content.
# Successfully saved Netclan20241144 content.
# Successfully saved Netclan20241145 content.
# Successfully saved Netclan20241146 content.
# Successfully saved Netclan20241147 content.
# Successfully saved Netclan20241148 content.
# Successfully saved Netclan20241149 content.
# Successfully saved Netclan20241150 content.
# Successfully saved Netclan20241151 content.
# Successfully saved Netclan20241152 content.
# Successfully saved Netclan20241153 content.
# Successfully saved Netclan20241154 content.
# Successfully saved Netclan20241155 content.
# Successfully saved Netclan20241156 content.
# Successfully saved Netclan20241157 content.
# Successfully saved Netclan20241158 content.
# Successfully saved Netclan20241159 content.
# Successfully saved Netclan20241160 content.
# Successfully saved Netclan20241161 content.
# Successfully saved Netclan20241162 content.
# Successfully saved Netclan20241163 content.

# %%
# import os
import nltk
from nltk.tokenize import word_tokenize

# Download punkt tokenizer if not already downloaded
nltk.download('punkt')

# Directories
text_dir = "C:/Users/Nidhi Dhameliya/Desktop/jupyter/Data_Extraction_and_Text_Analysis_for_Blackcoffer_company/TitleText"
stopwords_dir = "C:/Users/Nidhi Dhameliya/Desktop/jupyter/Data_Extraction_and_Text_Analysis_for_Blackcoffer_company/StopWords"
sentment_dir = "C:/Users/Nidhi Dhameliya/Desktop/jupyter/Data_Extraction_and_Text_Analysis_for_Blackcoffer_company/MasterDictionary"

# Function to load words from files into a set
def load_words_from_files(directory, encoding='ISO-8859-1'):
    words_set = set()
    for file in os.listdir(directory):
        with open(os.path.join(directory, file), 'r', encoding=encoding) as f:
            words_set.update(f.read().splitlines())
    return words_set

# Load stopwords
stop_words = load_words_from_files(stopwords_dir)

# Load positive and negative word lists individually
def load_words_from_file(file_path, encoding='ISO-8859-1'):
    with open(file_path, 'r', encoding=encoding) as f:
        return set(f.read().splitlines())

# Paths to positive and negative word files
positive_file = os.path.join(sentment_dir, 'positive-words.txt')
negative_file = os.path.join(sentment_dir, 'negative-words.txt')

# Load positive and negative words if files exist
if os.path.exists(positive_file):
    pos_words = load_words_from_file(positive_file)
else:
    print(f"Positive words file not found at: {positive_file}")
    pos_words = set()

if os.path.exists(negative_file):
    neg_words = load_words_from_file(negative_file)
else:
    print(f"Negative words file not found at: {negative_file}")
    neg_words = set()

# Remove any overlap between positive and negative words
unique_pos_words = pos_words - neg_words
unique_neg_words = neg_words - pos_words

# Load and process text files
docs = []
for text_file in os.listdir(text_dir):
    with open(os.path.join(text_dir, text_file), 'r', encoding='utf-8') as f:
        text = f.read()
        # Tokenize the given text file and remove stopwords
        words = word_tokenize(text)
        filtered_text = [word.lower() for word in words if word.lower() not in stop_words and word.isalpha()]
        docs.append(filtered_text)

# Sentiment analysis: Calculate scores
positive_words, negative_words = [], []
positive_score, negative_score = [], []
polarity_score, subjectivity_score = [], []

# Iterate through the list of docs
for doc in docs:
    # Find words in the document that match the positive and negative sets
    positive_words_in_doc = [word for word in doc if word in unique_pos_words]
    negative_words_in_doc = [word for word in doc if word in unique_neg_words]

    # Store found words for future reference
    positive_words.append(positive_words_in_doc)
    negative_words.append(negative_words_in_doc)

    # Calculate scores
    pos_score = len(positive_words_in_doc)
    neg_score = len(negative_words_in_doc)

    # Adjust scores to ensure they are not the same unless both are zero
    if pos_score == neg_score and pos_score > 0:
        neg_score += 1  # Slight adjustment to avoid identical scores

    # Append the scores to the lists
    positive_score.append(pos_score)
    negative_score.append(neg_score)

    # Calculate Polarity Score: (Positive Score – Negative Score) / ((Positive Score + Negative Score) + 0.000001)
    polarity = (pos_score - neg_score) / (pos_score + neg_score + 0.000001)
    polarity_score.append(polarity)

    # Calculate Subjectivity Score: (Positive Score + Negative Score) / ((Total Words after cleaning) + 0.000001)
    subjectivity = (pos_score + neg_score) / (len(doc) + 0.000001)  # Avoid division by zero
    subjectivity_score.append(subjectivity)

# Optionally, print or save the scores if needed
for i, doc in enumerate(docs):
    print(f"Document {i+1}:")
    print(f"  Positive Words: {positive_words[i]}")
    print(f"  Negative Words: {negative_words[i]}")
    print(f"  Positive Score: {positive_score[i]}")
    print(f"  Negative Score: {negative_score[i]}")
    print(f"  Polarity Score: {polarity_score[i]}")
    print(f"  Subjectivity Score: {subjectivity_score[i]}")
    print()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Nidhi
# [nltk_data]     Dhameliya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Document 1:
#   Positive Words: ['richer', 'leading', 'support', 'integrated', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 7
#   Negative Score: 1
#   Polarity Score: 0.7499999062500118
#   Subjectivity Score: 0.03652968019849461
#
# Document 2:
#   Positive Words: ['improved', 'richer', 'leading', 'lead', 'patient', 'proper', 'blessing', 'patient', 'blessing', 'patient', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'static', 'issues', 'issues', 'strictly', 'issues', 'issues', 'strictly']
#   Positive Score: 13
#   Negative Score: 8
#   Polarity Score: 0.23809522675737013
#   Subjectivity Score: 0.04516129022545959
#
# Document 3:
#   Positive Words: ['richer', 'leading', 'support', 'efficiently', 'streamlined', 'leading', 'comprehensive', 'accurately', 'effective', 'clear', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'lacks', 'difficulties']
#   Positive Score: 13
#   Negative Score: 3
#   Polarity Score: 0.6249999609375024
#   Subjectivity Score: 0.06557377022305833
#
# Document 4:
#   Positive Words: ['support']
#   Negative Words: ['error', 'incorrect', 'unsure']
#   Positive Score: 1
#   Negative Score: 3
#   Polarity Score: -0.49999987500003124
#   Subjectivity Score: 0.1481481426611799
#
# Document 5:
#   Positive Words: ['richer', 'robust', 'flexibility', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.032558139383450514
#
# Document 6:
#   Positive Words: ['richer', 'leading', 'support', 'integrated', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 7
#   Negative Score: 1
#   Polarity Score: 0.7499999062500118
#   Subjectivity Score: 0.03652968019849461
#
# Document 7:
#   Positive Words: ['improved', 'richer', 'leading', 'lead', 'patient', 'proper', 'blessing', 'patient', 'blessing', 'patient', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'static', 'issues', 'issues', 'strictly', 'issues', 'issues', 'strictly']
#   Positive Score: 13
#   Negative Score: 8
#   Polarity Score: 0.23809522675737013
#   Subjectivity Score: 0.04516129022545959
#
# Document 8:
#   Positive Words: ['richer', 'leading', 'support', 'efficiently', 'streamlined', 'leading', 'comprehensive', 'accurately', 'effective', 'clear', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'lacks', 'difficulties']
#   Positive Score: 13
#   Negative Score: 3
#   Polarity Score: 0.6249999609375024
#   Subjectivity Score: 0.06557377022305833
#
# Document 9:
#   Positive Words: ['support']
#   Negative Words: ['error', 'incorrect', 'unsure']
#   Positive Score: 1
#   Negative Score: 3
#   Polarity Score: -0.49999987500003124
#   Subjectivity Score: 0.1481481426611799
#
# Document 10:
#   Positive Words: ['support']
#   Negative Words: ['error', 'incorrect', 'unsure']
#   Positive Score: 1
#   Negative Score: 3
#   Polarity Score: -0.49999987500003124
#   Subjectivity Score: 0.1481481426611799
#
# Document 11:
#   Positive Words: ['improving', 'richer', 'leading', 'support', 'improve', 'enhance', 'exceed', 'comprehensive', 'improvement', 'effective', 'boost', 'efficiently', 'improve', 'reliable', 'accurately', 'proactive', 'reliable', 'accurately', 'proactive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'insufficient', 'lies', 'irrelevant', 'dropout', 'dense', 'irrelevant']
#   Positive Score: 22
#   Negative Score: 7
#   Polarity Score: 0.5172413614744358
#   Subjectivity Score: 0.08011049701626935
#
# Document 12:
#   Positive Words: ['sensitive', 'richer', 'leading', 'leading', 'sensitive', 'sensitive', 'powerful', 'secure', 'leverage', 'secure', 'support', 'support', 'seamless', 'comprehensive', 'robust', 'support', 'improvements', 'significant', 'efficient', 'efficient', 'enhanced', 'secure', 'confidence', 'leading', 'improved', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'limitations', 'risk']
#   Positive Score: 28
#   Negative Score: 3
#   Polarity Score: 0.8064515868886585
#   Subjectivity Score: 0.06753812621451388
#
# Document 13:
#   Positive Words: ['support']
#   Negative Words: ['error', 'incorrect', 'unsure']
#   Positive Score: 1
#   Negative Score: 3
#   Polarity Score: -0.49999987500003124
#   Subjectivity Score: 0.1481481426611799
#
# Document 14:
#   Positive Words: ['support']
#   Negative Words: ['error', 'incorrect', 'unsure']
#   Positive Score: 1
#   Negative Score: 3
#   Polarity Score: -0.49999987500003124
#   Subjectivity Score: 0.1481481426611799
#
# Document 15:
#   Positive Words: ['support']
#   Negative Words: ['error', 'incorrect', 'unsure']
#   Positive Score: 1
#   Negative Score: 3
#   Polarity Score: -0.49999987500003124
#   Subjectivity Score: 0.1481481426611799
#
# Document 16:
#   Positive Words: ['richer', 'leading', 'support', 'secure', 'supports', 'robust', 'gain', 'prompt', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud']
#   Positive Score: 11
#   Negative Score: 2
#   Polarity Score: 0.6923076390532585
#   Subjectivity Score: 0.047272727100826445
#
# Document 17:
#   Positive Words: ['richer', 'leading', 'support', 'facilitate', 'comprehensive', 'support', 'enhance', 'efficient', 'successfully', 'advanced', 'rapid', 'robust', 'seamless', 'modern', 'advanced', 'popular', 'flexibility', 'intuitive', 'responsive', 'effortlessly', 'swift', 'efficient', 'rapid', 'seamless', 'dynamic', 'advanced', 'efficiently', 'reliable', 'optimal', 'improve', 'paramount', 'robust', 'protect', 'sensitive', 'comprehensive', 'successful', 'significant', 'successful', 'advanced', 'positive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'critical', 'lies', 'restrict', 'latency', 'error', 'issues']
#   Positive Score: 43
#   Negative Score: 7
#   Polarity Score: 0.7199999856000003
#   Subjectivity Score: 0.08532423193630677
#
# Document 18:
#   Positive Words: ['richer', 'leading', 'support', 'successfully', 'promising', 'comprehensive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problem', 'limit', 'limits']
#   Positive Score: 9
#   Negative Score: 4
#   Polarity Score: 0.3846153550295881
#   Subjectivity Score: 0.060185184906550074
#
# Document 19:
#   Positive Words: ['comprehensive', 'richer', 'leading', 'support', 'popular', 'good', 'sustainability', 'efficient', 'skill', 'talent', 'innovation', 'continuity', 'valuable', 'innovation', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problem', 'limit', 'critical', 'risks']
#   Positive Score: 17
#   Negative Score: 5
#   Polarity Score: 0.5454545206611581
#   Subjectivity Score: 0.07260726048644468
#
# Document 20:
#   Positive Words: ['refresh', 'richer', 'leading', 'support', 'significant', 'refresh', 'improve', 'integrated', 'refresh', 'comprehensive', 'refresh', 'efficiently', 'improving', 'secure', 'reliable', 'efficiently', 'excel', 'excel', 'improved', 'enhanced', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'lacked', 'issues', 'limits', 'limits', 'issues', 'limits']
#   Positive Score: 23
#   Negative Score: 7
#   Polarity Score: 0.5333333155555561
#   Subjectivity Score: 0.09646302219786809
#
# Document 21:
#   Positive Words: ['enhanced', 'richer', 'leading', 'support', 'streamlined', 'improve', 'intuitive', 'ease', 'streamlined', 'enhanced', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud']
#   Positive Score: 13
#   Negative Score: 2
#   Polarity Score: 0.7333332844444478
#   Subjectivity Score: 0.05703422031545924
#
# Document 22:
#   Positive Words: ['richer', 'leading', 'improve', 'comprehensive', 'efficient', 'intuitive', 'improved', 'proactive', 'enhanced', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'complex']
#   Positive Score: 12
#   Negative Score: 3
#   Polarity Score: 0.5999999600000027
#   Subjectivity Score: 0.05434782589004411
#
# Document 23:
#   Positive Words: ['richer', 'leading', 'effective', 'comprehensive', 'understandable', 'efficient', 'improve', 'intuitive', 'proactive', 'improved', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'complex']
#   Positive Score: 13
#   Negative Score: 3
#   Polarity Score: 0.6249999609375024
#   Subjectivity Score: 0.05925925903978052
#
# Document 24:
#   Positive Words: ['advanced', 'integrated', 'richer', 'leading', 'advanced', 'effectively', 'dynamic', 'advanced', 'comprehensive', 'insightful', 'advanced', 'intuitive', 'enhanced', 'improved', 'dynamic', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud']
#   Positive Score: 18
#   Negative Score: 2
#   Polarity Score: 0.799999960000002
#   Subjectivity Score: 0.0754716978284087
#
# Document 25:
#   Positive Words: ['advanced', 'patient', 'improved', 'richer', 'leading', 'advanced', 'patient', 'improve', 'sensitive', 'comprehensive', 'patient', 'sensitive', 'robust', 'intuitive', 'improved', 'patient', 'proactive', 'enhanced', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'complex']
#   Positive Score: 21
#   Negative Score: 3
#   Polarity Score: 0.7499999687500013
#   Subjectivity Score: 0.08988764011278037
#
# Document 26:
#   Positive Words: ['enhanced', 'bright', 'richer', 'leading', 'support', 'improve', 'robust', 'comprehensive', 'comprehensive', 'improve', 'efficient', 'improved', 'bright', 'proactive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['anomaly', 'fatigue', 'unusual', 'anomaly', 'anomaly', 'anomaly', 'anomaly', 'cloud', 'anomaly', 'unusual']
#   Positive Score: 17
#   Negative Score: 10
#   Polarity Score: 0.2592592496570648
#   Subjectivity Score: 0.09677419320152619
#
# Document 27:
#   Positive Words: ['richer', 'leading', 'support', 'leverage', 'advanced', 'efficient', 'valuable', 'confidence', 'success', 'comprehensive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 13
#   Negative Score: 1
#   Polarity Score: 0.8571427959183717
#   Subjectivity Score: 0.051851851659807956
#
# Document 28:
#   Positive Words: ['richer', 'leading', 'sophisticated', 'capable', 'leverage', 'accurately', 'winners', 'efficiently', 'enhance', 'comprehensive', 'dedicated', 'suitable', 'accurate', 'great', 'lead', 'improved', 'significant', 'successful', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'cloud']
#   Positive Score: 21
#   Negative Score: 3
#   Polarity Score: 0.7499999687500013
#   Subjectivity Score: 0.06266318521497863
#
# Document 29:
#   Positive Words: ['efficient', 'richer', 'leading', 'efficiently', 'leading', 'efficiently', 'work', 'exceed', 'popular', 'powerful', 'improved', 'valuable', 'work', 'exceed', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'inefficient', 'inadequate', 'inefficient', 'excessively']
#   Positive Score: 17
#   Negative Score: 5
#   Polarity Score: 0.5454545206611581
#   Subjectivity Score: 0.06666666646464646
#
# Document 30:
#   Positive Words: ['richer', 'leading', 'effectively', 'leads', 'important', 'top', 'effective', 'enhance', 'improved', 'comprehensive', 'streamlined', 'valuable', 'improved', 'improvements', 'led', 'enhanced', 'accurate', 'timely', 'effectively', 'significant', 'leading', 'improved', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['cloud', 'fatigue', 'difficult', 'cloud', 'accidental', 'cloud', 'struggling', 'difficult', 'cloud']
#   Positive Score: 25
#   Negative Score: 9
#   Polarity Score: 0.47058822145328766
#   Subjectivity Score: 0.07472527456104336
#
# Document 31:
#   Positive Words: ['richer', 'leading', 'ease', 'flexibility', 'popular', 'secure', 'secure', 'successfully', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'critical', 'problem', 'cloud']
#   Positive Score: 11
#   Negative Score: 4
#   Polarity Score: 0.46666663555555765
#   Subjectivity Score: 0.04687499985351563
#
# Document 32:
#   Positive Words: ['richer', 'leading', 'robust', 'integrated', 'secure', 'advanced', 'dynamic', 'intuitive', 'enhances', 'seamless', 'seasoned', 'comprehensive', 'successfully', 'reliable', 'dynamic', 'responsive', 'improve', 'meticulous', 'successfully', 'robust', 'effectively', 'successfully', 'meticulous', 'robust', 'effectively', 'accessible', 'dynamic', 'responsive', 'responsive', 'seamless', 'helped', 'enhance', 'robust', 'enhanced', 'successful', 'significant', 'positive', 'sophisticated', 'comprehensive', 'intuitive', 'enhanced', 'robust', 'trust', 'reliable', 'competitive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'difficulties', 'inconsistencies', 'limitations', 'error', 'complex', 'latency', 'concerns', 'error', 'inconsistencies', 'limits', 'complex', 'latency', 'critical']
#   Positive Score: 48
#   Negative Score: 14
#   Polarity Score: 0.5483870879292405
#   Subjectivity Score: 0.11231884037623399
#
# Document 33:
#   Positive Words: ['dependable', 'richer', 'leading', 'wise', 'wise', 'progress', 'dependable', 'work', 'correct', 'progress', 'dependable', 'comprehensive', 'significant', 'positive', 'lead', 'motivated', 'productive', 'enhanced', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'drain', 'limited', 'drain', 'limited']
#   Positive Score: 21
#   Negative Score: 5
#   Polarity Score: 0.6153845917159773
#   Subjectivity Score: 0.05210420831241642
#
# Document 34:
#   Positive Words: ['richer', 'leading', 'works', 'securely', 'robust', 'proactive', 'effectively', 'secure', 'robust', 'promptly', 'smooth', 'successful', 'led', 'improved', 'enhanced', 'streamlined', 'competitive', 'advantage', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issues', 'error', 'issues', 'cloud', 'error', 'issues']
#   Positive Score: 21
#   Negative Score: 7
#   Polarity Score: 0.49999998214285774
#   Subjectivity Score: 0.08641975281969212
#
# Document 35:
#   Positive Words: ['richer', 'leading', 'meaningful', 'efficient', 'leading', 'streamlined', 'clean', 'intuitive', 'robust', 'dynamic', 'faster', 'accurate', 'clean', 'proper', 'secure', 'accessible', 'clean', 'proper', 'secure', 'accessible', 'smooth', 'proper', 'proper', 'restful', 'protect', 'sensitive', 'sensitive', 'comprehensive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'challenging', 'delayed', 'problem', 'noise', 'inconsistencies', 'error', 'static', 'static', 'noise', 'inconsistencies', 'error', 'errors', 'error', 'error', 'errors', 'issues', 'bugs', 'noise', 'cloud', 'strict', 'limit', 'bugs', 'issues']
#   Positive Score: 31
#   Negative Score: 24
#   Polarity Score: 0.12727272495867772
#   Subjectivity Score: 0.05933117577202678
#
# Document 36:
#   Positive Words: ['richer', 'leading', 'support', 'efficiently', 'support', 'enhance', 'suitable', 'suitable', 'comprehensive', 'robust', 'clean', 'facilitate', 'supported', 'leverage', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'errors', 'inefficient', 'issues', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'inconsistencies', 'challenging', 'inconsistencies', 'issues']
#   Positive Score: 17
#   Negative Score: 20
#   Polarity Score: -0.08108107888970058
#   Subjectivity Score: 0.06654676247023963
#
# Document 37:
#   Positive Words: ['richer', 'leading', 'significant', 'confidence', 'significant', 'sufficient', 'significant', 'significant', 'significant', 'clear', 'concise', 'advanced', 'accurate', 'easier', 'easier', 'advanced', 'effectively', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'reject', 'fail', 'reject', 'manipulation', 'complex']
#   Positive Score: 20
#   Negative Score: 6
#   Polarity Score: 0.5384615177514801
#   Subjectivity Score: 0.04577464780673478
#
# Document 38:
#   Positive Words: ['richer', 'efficient', 'patient', 'seamless', 'works', 'powerful', 'comprehensive', 'capable', 'robust', 'reliable', 'accessible', 'sustainable', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'subjected']
#   Positive Score: 15
#   Negative Score: 2
#   Polarity Score: 0.7647058373702448
#   Subjectivity Score: 0.05414012721611425
#
# Document 39:
#   Positive Words: ['richer', 'leading', 'patient', 'dynamic', 'enhance', 'patient', 'patient', 'patient', 'patient', 'patient', 'patient', 'correct', 'patient', 'great', 'patient', 'patient', 'patient', 'patient', 'patient', 'patient', 'correct', 'patient', 'great', 'patient', 'patient', 'patient', 'correct', 'patient', 'correct', 'patient', 'patient', 'great', 'patient', 'prefer', 'patient', 'patient', 'patient', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issues', 'incorrect', 'difficulty']
#   Positive Score: 40
#   Negative Score: 4
#   Polarity Score: 0.8181817995867773
#   Subjectivity Score: 0.08576998033962967
#
# Document 40:
#   Positive Words: ['richer', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 4
#   Negative Score: 1
#   Polarity Score: 0.599999880000024
#   Subjectivity Score: 0.03424657510790017
#
# Document 41:
#   Positive Words: ['recommendation', 'richer', 'leading', 'works', 'recommendation', 'recommend', 'recommendation', 'recommendation', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'static', 'slack']
#   Positive Score: 13
#   Negative Score: 3
#   Polarity Score: 0.6249999609375024
#   Subjectivity Score: 0.057142856938775514
#
# Document 42:
#   Positive Words: ['dynamic', 'richer', 'leading', 'leads', 'clean', 'dynamic', 'important', 'leads', 'leads', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 14
#   Negative Score: 2
#   Polarity Score: 0.7499999531250029
#   Subjectivity Score: 0.07079645986373248
#
# Document 43:
#   Positive Words: ['richer', 'leading', 'meaningful', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 8
#   Negative Score: 2
#   Polarity Score: 0.599999940000006
#   Subjectivity Score: 0.03906249984741211
#
# Document 44:
#   Positive Words: ['richer', 'leading', 'leads', 'work', 'easy', 'leads', 'leads', 'clean', 'leads', 'lead', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'limitation', 'zaps', 'limitation', 'slack']
#   Positive Score: 15
#   Negative Score: 5
#   Polarity Score: 0.4999999750000012
#   Subjectivity Score: 0.07434944210279018
#
# Document 45:
#   Positive Words: ['richer', 'leading', 'leads', 'work', 'neat', 'clean', 'easy', 'hot', 'lead', 'lead', 'integrated', 'integrated', 'leads', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'challenging', 'limitation', 'limited', 'issue', 'hard', 'challenging', 'miss', 'slack']
#   Positive Score: 18
#   Negative Score: 9
#   Polarity Score: 0.3333333209876548
#   Subjectivity Score: 0.09374999967447917
#
# Document 46:
#   Positive Words: ['richer', 'leading', 'excel', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'scrap', 'problems', 'scrap', 'slack']
#   Positive Score: 8
#   Negative Score: 5
#   Polarity Score: 0.23076921301775286
#   Subjectivity Score: 0.04347826072415297
#
# Document 47:
#   Positive Words: ['richer', 'leading', 'lead', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'slack']
#   Positive Score: 8
#   Negative Score: 3
#   Polarity Score: 0.4545454132231443
#   Subjectivity Score: 0.04471544697270143
#
# Document 48:
#   Positive Words: ['richer', 'leading', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 7
#   Negative Score: 2
#   Polarity Score: 0.5555554938271674
#   Subjectivity Score: 0.04999999972222222
#
# Document 49:
#   Positive Words: ['richer', 'leading', 'faster', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'errors', 'errors', 'slack']
#   Positive Score: 8
#   Negative Score: 4
#   Polarity Score: 0.3333333055555579
#   Subjectivity Score: 0.07361963145018631
#
# Document 50:
#   Positive Words: ['richer', 'leading', 'work', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 8
#   Negative Score: 2
#   Polarity Score: 0.599999940000006
#   Subjectivity Score: 0.05714285681632653
#
# Document 51:
#   Positive Words: ['richer', 'leading', 'competitive', 'intelligence', 'suitable', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'limited', 'slack']
#   Positive Score: 10
#   Negative Score: 3
#   Polarity Score: 0.5384614970414233
#   Subjectivity Score: 0.05603448251709275
#
# Document 52:
#   Positive Words: ['richer', 'leading', 'variety', 'great', 'tough', 'easy', 'fast', 'effective', 'excel', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 14
#   Negative Score: 2
#   Polarity Score: 0.7499999531250029
#   Subjectivity Score: 0.05925925903978052
#
# Document 53:
#   Positive Words: ['richer', 'leading', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'regression', 'slack']
#   Positive Score: 7
#   Negative Score: 3
#   Polarity Score: 0.39999996000000404
#   Subjectivity Score: 0.05617977496528216
#
# Document 54:
#   Positive Words: ['richer', 'leading', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'cloud', 'issues', 'slack']
#   Positive Score: 7
#   Negative Score: 5
#   Polarity Score: 0.16666665277777895
#   Subjectivity Score: 0.04347826071203529
#
# Document 55:
#   Positive Words: ['richer', 'leading', 'important', 'worked', 'excel', 'logical', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'loss', 'slack']
#   Positive Score: 11
#   Negative Score: 3
#   Polarity Score: 0.5714285306122479
#   Subjectivity Score: 0.045454545306965764
#
# Document 56:
#   Positive Words: ['richer', 'leading', 'recommendations', 'feasible', 'complements', 'successfully', 'successfully', 'stable', 'effectively', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'object', 'issues', 'issues', 'errors', 'issues', 'slack']
#   Positive Score: 14
#   Negative Score: 7
#   Polarity Score: 0.3333333174603182
#   Subjectivity Score: 0.09502262400442252
#
# Document 57:
#   Positive Words: ['golden', 'richer', 'leading', 'perfect', 'golden', 'perfect', 'perfect', 'worked', 'work', 'recover', 'perfect', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issues', 'fails', 'issues', 'slack']
#   Positive Score: 16
#   Negative Score: 5
#   Polarity Score: 0.5238094988662143
#   Subjectivity Score: 0.07473309581945517
#
# Document 58:
#   Positive Words: ['advanced', 'richer', 'leading', 'integrated', 'fast', 'top', 'integrated', 'faster', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'issue', 'slack']
#   Positive Score: 13
#   Negative Score: 4
#   Polarity Score: 0.5294117335640156
#   Subjectivity Score: 0.05862068945303211
#
# Document 59:
#   Positive Words: ['recommendations', 'richer', 'leading', 'recommendations', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slow', 'complex', 'difficult', 'cloud', 'slack']
#   Positive Score: 9
#   Negative Score: 6
#   Polarity Score: 0.19999998666666757
#   Subjectivity Score: 0.07894736800554017
#
# Document 60:
#   Positive Words: ['advanced', 'richer', 'leading', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 8
#   Negative Score: 2
#   Polarity Score: 0.599999940000006
#   Subjectivity Score: 0.06211180085644844
#
# Document 61:
#   Positive Words: ['advanced', 'richer', 'leading', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['threat', 'fatigue', 'threat', 'threat', 'slack']
#   Positive Score: 8
#   Negative Score: 5
#   Polarity Score: 0.23076921301775286
#   Subjectivity Score: 0.07602339136828426
#
# Document 62:
#   Positive Words: ['advanced', 'richer', 'leading', 'works', 'work', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'inefficient', 'manipulate', 'slack']
#   Positive Score: 10
#   Negative Score: 4
#   Polarity Score: 0.42857139795918586
#   Subjectivity Score: 0.07865168495139503
#
# Document 63:
#   Positive Words: ['advanced', 'richer', 'leading', 'good', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack']
#   Positive Score: 9
#   Negative Score: 2
#   Polarity Score: 0.636363578512402
#   Subjectivity Score: 0.06666666626262627
#
# Document 64:
#   Positive Words: ['richer', 'leading', 'leverage', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issue', 'unwanted', 'inaccurate', 'inaccurate', 'complex', 'difficulty', 'slack']
#   Positive Score: 8
#   Negative Score: 9
#   Polarity Score: -0.05882352595155729
#   Subjectivity Score: 0.0871794867324129
#
# Document 65:
#   Positive Words: ['richer', 'leading', 'worked', 'perfectly', 'fine', 'success', 'happy', 'worked', 'perfectly', 'fine', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack', 'slack']
#   Positive Score: 15
#   Negative Score: 3
#   Polarity Score: 0.6666666296296316
#   Subjectivity Score: 0.06792452804556783
#
# Document 66:
#   Positive Words: ['richer', 'leading', 'accurately', 'excel', 'clean', 'capable', 'efficient', 'improved', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'challenging', 'difficult', 'issues', 'slack']
#   Positive Score: 13
#   Negative Score: 5
#   Polarity Score: 0.4444444197530878
#   Subjectivity Score: 0.062283736808706795
#
# Document 67:
#   Positive Words: ['richer', 'leading', 'cheaper', 'cheaper', 'refreshed', 'readable', 'excel', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issues', 'cloud', 'cloud', 'expensive']
#   Positive Score: 10
#   Negative Score: 5
#   Polarity Score: 0.3333333111111126
#   Subjectivity Score: 0.04838709661810614
#
# Document 68:
#   Positive Words: ['richer', 'leading', 'readable', 'excel', 'readable', 'excel', 'readable', 'correct', 'excel', 'readable', 'correct', 'readable', 'excel', 'readable', 'correct', 'readable', 'readable', 'recommend', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'dirty', 'split', 'hard', 'split', 'hard', 'difficult', 'dirty', 'split', 'hard', 'manipulate', 'hard', 'slack']
#   Positive Score: 22
#   Negative Score: 13
#   Polarity Score: 0.2571428497959186
#   Subjectivity Score: 0.10115606907180327
#
# Document 69:
#   Positive Words: ['richer', 'leading', 'appealing', 'comprehensive', 'helped', 'comprehensive', 'clear', 'helped', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issue']
#   Positive Score: 11
#   Negative Score: 2
#   Polarity Score: 0.6923076390532585
#   Subjectivity Score: 0.04290429028744459
#
# Document 70:
#   Positive Words: ['richer', 'leading', 'leads', 'important', 'appealing', 'appealing', 'leads', 'helped', 'improve', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 12
#   Negative Score: 1
#   Polarity Score: 0.8461537810650938
#   Subjectivity Score: 0.0469314077728108
#
# Document 71:
#   Positive Words: ['richer', 'leading', 'effectively', 'effectiveness', 'comprehensive', 'comprehensive', 'easy', 'appealing', 'intuitive', 'intuitive', 'support', 'seamless', 'efficient', 'enhanced', 'significant', 'positive', 'gained', 'valuable', 'effectiveness', 'leading', 'improved', 'streamlined', 'improved', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problem', 'lack', 'lacked', 'challenging']
#   Positive Score: 26
#   Negative Score: 5
#   Polarity Score: 0.677419332986473
#   Subjectivity Score: 0.05927342244880799
#
# Document 72:
#   Positive Words: ['richer', 'leading', 'hot', 'helped', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'errors', 'flair']
#   Positive Score: 7
#   Negative Score: 3
#   Polarity Score: 0.39999996000000404
#   Subjectivity Score: 0.042372881176386094
#
# Document 73:
#   Positive Words: ['richer', 'leading', 'work', 'work', 'work', 'refresh', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 9
#   Negative Score: 1
#   Polarity Score: 0.7999999200000081
#   Subjectivity Score: 0.03389830496983626
#
# Document 74:
#   Positive Words: ['richer', 'leading', 'safe', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'bother']
#   Positive Score: 6
#   Negative Score: 2
#   Polarity Score: 0.4999999375000079
#   Subjectivity Score: 0.05128205095332019
#
# Document 75:
#   Positive Words: ['richer', 'leading', 'top', 'top', 'attractive', 'cheaper', 'accurate', 'accurate', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problems', 'poor']
#   Positive Score: 11
#   Negative Score: 3
#   Polarity Score: 0.5714285306122479
#   Subjectivity Score: 0.05405405384535114
#
# Document 76:
#   Positive Words: ['richer', 'leading', 'excel', 'good', 'excel', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'regression', 'regression']
#   Positive Score: 8
#   Negative Score: 3
#   Polarity Score: 0.4545454132231443
#   Subjectivity Score: 0.04198473266418041
#
# Document 77:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.03389830489322992
#
# Document 78:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['anomaly', 'problems', 'fatigue', 'anomaly', 'problems', 'anomaly', 'anomaly', 'problems']
#   Positive Score: 5
#   Negative Score: 8
#   Polarity Score: -0.23076921301775286
#   Subjectivity Score: 0.06341463383700179
#
# Document 79:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'cloud', 'cloud', 'cloud', 'cloud', 'cloud', 'cloud', 'cloud', 'cloud', 'cloud']
#   Positive Score: 5
#   Negative Score: 11
#   Polarity Score: -0.37499997656250145
#   Subjectivity Score: 0.06425702785438944
#
# Document 80:
#   Positive Words: ['richer', 'leading', 'accessible', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.025925925829903978
#
# Document 81:
#   Positive Words: ['richer', 'leading', 'worked', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.04487179458415516
#
# Document 82:
#   Positive Words: ['richer', 'leading', 'cheapest', 'flutter', 'cheapest', 'flutter', 'flutter', 'proper', 'logical', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problems']
#   Positive Score: 12
#   Negative Score: 2
#   Polarity Score: 0.7142856632653098
#   Subjectivity Score: 0.0693069303499657
#
# Document 83:
#   Positive Words: ['richer', 'leading', 'valuable', 'easier', 'refreshing', 'efficiently', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'mundane', 'waste', 'cloud', 'errors', 'dull']
#   Positive Score: 9
#   Negative Score: 6
#   Polarity Score: 0.19999998666666757
#   Subjectivity Score: 0.06355932176457915
#
# Document 84:
#   Positive Words: ['richer', 'leading', 'dynamic', 'modern', 'protect', 'meaningful', 'proper', 'easier', 'support', 'work', 'meaningful', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'unwanted', 'cloud', 'problems']
#   Positive Score: 14
#   Negative Score: 4
#   Polarity Score: 0.5555555246913597
#   Subjectivity Score: 0.06569343041717726
#
# Document 85:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.027649769457835163
#
# Document 86:
#   Positive Words: ['progress', 'richer', 'leading', 'progress', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 7
#   Negative Score: 1
#   Polarity Score: 0.7499999062500118
#   Subjectivity Score: 0.04819277079401946
#
# Document 87:
#   Positive Words: ['richer', 'leading', 'readily', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'plot']
#   Positive Score: 6
#   Negative Score: 2
#   Polarity Score: 0.4999999375000079
#   Subjectivity Score: 0.04145077698730167
#
# Document 88:
#   Positive Words: ['richer', 'leading', 'faster', 'consistently', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problem']
#   Positive Score: 7
#   Negative Score: 2
#   Polarity Score: 0.5555554938271674
#   Subjectivity Score: 0.04017857124920281
#
# Document 89:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.028846153707470415
#
# Document 90:
#   Positive Words: ['refund', 'richer', 'leading', 'refund', 'refund', 'easy', 'refund', 'refund', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'issue']
#   Positive Score: 11
#   Negative Score: 2
#   Polarity Score: 0.6923076390532585
#   Subjectivity Score: 0.06701030893293655
#
# Document 91:
#   Positive Words: ['richer', 'correct', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'wrong', 'wrong', 'wrong', 'wrong', 'wrong', 'cloud']
#   Positive Score: 5
#   Negative Score: 7
#   Polarity Score: -0.16666665277777895
#   Subjectivity Score: 0.05309734489779936
#
# Document 92:
#   Positive Words: ['richer', 'leading', 'improve', 'integral', 'improve', 'variety', 'handy', 'safely', 'simplify', 'important', 'gains', 'improvement', 'works', 'improve', 'important', 'improve', 'free', 'loyalty', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problem', 'lapse']
#   Positive Score: 21
#   Negative Score: 3
#   Polarity Score: 0.7499999687500013
#   Subjectivity Score: 0.04887983696765817
#
# Document 93:
#   Positive Words: ['richer', 'simpler', 'readily', 'work', 'improvements', 'integral', 'improve', 'variety', 'handy', 'safely', 'simplify', 'important', 'important', 'improve', 'important', 'free', 'work', 'important', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'difficult']
#   Positive Score: 21
#   Negative Score: 2
#   Polarity Score: 0.8260869206049165
#   Subjectivity Score: 0.045186640382737446
#
# Document 94:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.03846153821499014
#
# Document 95:
#   Positive Words: ['richer', 'leading', 'robust', 'dynamic', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'error', 'issue']
#   Positive Score: 7
#   Negative Score: 4
#   Polarity Score: 0.2727272479338866
#   Subjectivity Score: 0.04583333314236111
#
# Document 96:
#   Positive Words: ['richer', 'leading', 'worked', 'work', 'sufficient', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['errors', 'fatigue', 'issue']
#   Positive Score: 8
#   Negative Score: 3
#   Polarity Score: 0.4545454132231443
#   Subjectivity Score: 0.05641025612097304
#
# Document 97:
#   Positive Words: ['robust', 'richer', 'leading', 'proper', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'slack', 'complex', 'insufficient', 'issues']
#   Positive Score: 7
#   Negative Score: 5
#   Polarity Score: 0.16666665277777895
#   Subjectivity Score: 0.048979591636818
#
# Document 98:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'error']
#   Positive Score: 5
#   Negative Score: 2
#   Polarity Score: 0.4285713673469475
#   Subjectivity Score: 0.03167420800147417
#
# Document 99:
#   Positive Words: ['richer', 'leading', 'helping', 'good', 'comprehensive', 'comprehensive', 'excel', 'excel', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'limited', 'cloud']
#   Positive Score: 11
#   Negative Score: 3
#   Polarity Score: 0.5714285306122479
#   Subjectivity Score: 0.049295774474310654
#
# Document 100:
#   Positive Words: ['richer', 'leading', 'good', 'good', 'good', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 8
#   Negative Score: 1
#   Polarity Score: 0.7777776913580343
#   Subjectivity Score: 0.042654028233867165
#
# Document 101:
#   Positive Words: ['richer', 'leading', 'success', 'improvement', 'success', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['complex', 'fatigue', 'lies', 'failure']
#   Positive Score: 8
#   Negative Score: 4
#   Polarity Score: 0.3333333055555579
#   Subjectivity Score: 0.04761904743008315
#
# Document 102:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'inactive']
#   Positive Score: 5
#   Negative Score: 2
#   Polarity Score: 0.4285713673469475
#   Subjectivity Score: 0.041916167413675647
#
# Document 103:
#   Positive Words: ['richer', 'leading', 'excel', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'regression', 'regression']
#   Positive Score: 6
#   Negative Score: 3
#   Polarity Score: 0.33333329629630043
#   Subjectivity Score: 0.03543307072664145
#
# Document 104:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.046153845798816574
#
# Document 105:
#   Positive Words: ['leads', 'richer', 'leading', 'win', 'leads', 'readily', 'important', 'important', 'excel', 'excel', 'rapid', 'excel', 'free', 'lead', 'clean', 'trusted', 'win', 'lead', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'difficult', 'dispute']
#   Positive Score: 21
#   Negative Score: 4
#   Polarity Score: 0.679999972800001
#   Subjectivity Score: 0.06082725046027433
#
# Document 106:
#   Positive Words: ['richer', 'leading', 'fun', 'fun', 'cheapest', 'good', 'fun', 'integrated', 'fast', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 12
#   Negative Score: 1
#   Polarity Score: 0.8461537810650938
#   Subjectivity Score: 0.047101449104704894
#
# Document 107:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'bash', 'cloud']
#   Positive Score: 5
#   Negative Score: 3
#   Polarity Score: 0.24999996875000394
#   Subjectivity Score: 0.029850746157273334
#
# Document 108:
#   Positive Words: ['richer', 'leading', 'advanced', 'dynamic', 'dynamic', 'hero', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 9
#   Negative Score: 1
#   Polarity Score: 0.7999999200000081
#   Subjectivity Score: 0.053475935542909435
#
# Document 109:
#   Positive Words: ['innovation', 'richer', 'leading', 'ready', 'clean', 'clean', 'excel', 'clean', 'clean', 'ready', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'noisy', 'noise', 'difficult', 'difficult']
#   Positive Score: 13
#   Negative Score: 5
#   Polarity Score: 0.4444444197530878
#   Subjectivity Score: 0.07531380721626023
#
# Document 110:
#   Positive Words: ['richer', 'variety', 'great', 'safe', 'good', 'beauty', 'lead', 'simplifying', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'worry', 'expensive', 'unable']
#   Positive Score: 11
#   Negative Score: 4
#   Polarity Score: 0.46666663555555765
#   Subjectivity Score: 0.056179775070487735
#
# Document 111:
#   Positive Words: ['traction', 'richer', 'super', 'smart', 'successful', 'works', 'free', 'work', 'free', 'free', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'cloud']
#   Positive Score: 13
#   Negative Score: 3
#   Polarity Score: 0.6249999609375024
#   Subjectivity Score: 0.045584045454176506
#
# Document 112:
#   Positive Words: ['richer', 'leading', 'variety', 'great', 'win', 'win', 'clean', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'unwanted', 'cloud']
#   Positive Score: 10
#   Negative Score: 3
#   Polarity Score: 0.5384614970414233
#   Subjectivity Score: 0.05263157873428511
#
# Document 113:
#   Positive Words: ['richer', 'leading', 'variety', 'great', 'win', 'win', 'easy', 'convenient', 'easy', 'affordable', 'perfect', 'great', 'friendly', 'recommendation', 'futuristic', 'outstanding', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 19
#   Negative Score: 1
#   Polarity Score: 0.8999999550000022
#   Subjectivity Score: 0.07462686539318333
#
# Document 114:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.039735099074601994
#
# Document 115:
#   Positive Words: ['richer', 'verifiable', 'favour', 'valuable', 'trust', 'work', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'distrust']
#   Positive Score: 9
#   Negative Score: 2
#   Polarity Score: 0.636363578512402
#   Subjectivity Score: 0.0536585363236169
#
# Document 116:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'cloud', 'cloud']
#   Positive Score: 5
#   Negative Score: 3
#   Polarity Score: 0.24999996875000394
#   Subjectivity Score: 0.044198894783431524
#
# Document 117:
#   Positive Words: ['richer', 'leading', 'integrated', 'integrated', 'friendly', 'refresh', 'refresh', 'refresh', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 11
#   Negative Score: 1
#   Polarity Score: 0.8333332638888947
#   Subjectivity Score: 0.04363636347768595
#
# Document 118:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.024489795818409
#
# Document 119:
#   Positive Words: ['richer', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 4
#   Negative Score: 1
#   Polarity Score: 0.599999880000024
#   Subjectivity Score: 0.03875968962201791
#
# Document 120:
#   Positive Words: ['leading', 'richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.042944785012608684
#
# Document 121:
#   Positive Words: ['leading', 'richer', 'leading', 'feasible', 'improve', 'improvement', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 9
#   Negative Score: 1
#   Polarity Score: 0.7999999200000081
#   Subjectivity Score: 0.058823529065743944
#
# Document 122:
#   Positive Words: ['leading', 'richer', 'leading', 'dynamic', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'broken', 'error']
#   Positive Score: 7
#   Negative Score: 3
#   Polarity Score: 0.39999996000000404
#   Subjectivity Score: 0.0636942671102276
#
# Document 123:
#   Positive Words: ['leading', 'instrumental', 'richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'error']
#   Positive Score: 7
#   Negative Score: 2
#   Polarity Score: 0.5555554938271674
#   Subjectivity Score: 0.059999999600000006
#
# Document 124:
#   Positive Words: ['leading', 'richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'rail']
#   Positive Score: 6
#   Negative Score: 2
#   Polarity Score: 0.4999999375000079
#   Subjectivity Score: 0.05298013209946933
#
# Document 125:
#   Positive Words: ['recommendations', 'richer', 'leading', 'excel', 'work', 'excel', 'excel', 'enhance', 'improving', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 12
#   Negative Score: 1
#   Polarity Score: 0.8461537810650938
#   Subjectivity Score: 0.05371900804248344
#
# Document 126:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.03428571408979592
#
# Document 127:
#   Positive Words: ['richer', 'leading', 'clean', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'regression', 'debt', 'repetitive', 'incomplete', 'manipulation', 'slow', 'difficult', 'difficulty']
#   Positive Score: 6
#   Negative Score: 9
#   Polarity Score: -0.19999998666666757
#   Subjectivity Score: 0.04658385078700668
#
# Document 128:
#   Positive Words: ['instrumental', 'richer', 'leading', 'instrumental', 'instrumental', 'easy', 'fast', 'faster', 'instrumental', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['splitting', 'fatigue', 'split', 'isolated']
#   Positive Score: 12
#   Negative Score: 4
#   Polarity Score: 0.4999999687500019
#   Subjectivity Score: 0.07272727239669421
#
# Document 129:
#   Positive Words: ['richer', 'leading', 'variety', 'personalized', 'effectiveness', 'helped', 'advanced', 'integrated', 'tough', 'excel', 'proper', 'excel', 'authentic', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'difficulty', 'impossible']
#   Positive Score: 16
#   Negative Score: 3
#   Polarity Score: 0.684210490304711
#   Subjectivity Score: 0.06690140821513589
#
# Document 130:
#   Positive Words: ['recommendations', 'richer', 'leading', 'master', 'master', 'master', 'enhance', 'improving', 'support', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'manipulation', 'manipulation', 'cloud']
#   Positive Score: 12
#   Negative Score: 4
#   Polarity Score: 0.4999999687500019
#   Subjectivity Score: 0.06722689047383659
#
# Document 131:
#   Positive Words: ['richer', 'leading', 'beautiful', 'important', 'capability', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 8
#   Negative Score: 1
#   Polarity Score: 0.7777776913580343
#   Subjectivity Score: 0.0351562498626709
#
# Document 132:
#   Positive Words: ['traction', 'richer', 'leading', 'excel', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'problem']
#   Positive Score: 7
#   Negative Score: 2
#   Polarity Score: 0.5555554938271674
#   Subjectivity Score: 0.03529411750865052
#
# Document 133:
#   Positive Words: ['richer', 'leading', 'proper', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.03763440839981501
#
# Document 134:
#   Positive Words: ['richer', 'leading', 'correct', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['missed', 'fatigue', 'missed']
#   Positive Score: 6
#   Negative Score: 3
#   Polarity Score: 0.33333329629630043
#   Subjectivity Score: 0.04812834198861849
#
# Document 135:
#   Positive Words: ['leads', 'richer', 'leading', 'proper', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 7
#   Negative Score: 1
#   Polarity Score: 0.7499999062500118
#   Subjectivity Score: 0.04519773985763989
#
# Document 136:
#   Positive Words: ['leads', 'richer', 'leading', 'proper', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 7
#   Negative Score: 1
#   Polarity Score: 0.7499999062500118
#   Subjectivity Score: 0.043715846755651114
#
# Document 137:
#   Positive Words: ['leads', 'richer', 'leading', 'faster', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 7
#   Negative Score: 1
#   Polarity Score: 0.7499999062500118
#   Subjectivity Score: 0.04545454519628099
#
# Document 138:
#   Positive Words: ['leads', 'richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.04166666641865079
#
# Document 139:
#   Positive Words: ['leads', 'richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 6
#   Negative Score: 1
#   Polarity Score: 0.7142856122449125
#   Subjectivity Score: 0.04117647034602076
#
# Document 140:
#   Positive Words: ['richer', 'leading', 'bright', 'bright', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'randomly', 'cloud']
#   Positive Score: 7
#   Negative Score: 3
#   Polarity Score: 0.39999996000000404
#   Subjectivity Score: 0.04926108350117693
#
# Document 141:
#   Positive Words: ['richer', 'leading', 'strong', 'strong', 'strong', 'sublime', 'reliable', 'rapid', 'advantages', 'progress', 'powerful', 'proper', 'proper', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'complex', 'complex', 'issue', 'unwanted', 'cloud', 'complex', 'breaking', 'complex']
#   Positive Score: 16
#   Negative Score: 9
#   Polarity Score: 0.27999998880000043
#   Subjectivity Score: 0.044014084429552666
#
# Document 142:
#   Positive Words: ['richer', 'leading', 'positive', 'positive', 'sublime', 'reliable', 'worked', 'positive', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'negative', 'cloud', 'cloud', 'negative', 'plot', 'plot']
#   Positive Score: 11
#   Negative Score: 7
#   Polarity Score: 0.2222222098765439
#   Subjectivity Score: 0.051282051135948574
#
# Document 143:
#   Positive Words: ['richer', 'leading', 'proper', 'strong', 'sublime', 'advanced', 'excel', 'reliable', 'rapid', 'advantages', 'progress', 'powerful', 'proper', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'unable', 'plot', 'plot', 'plot', 'plot', 'plot', 'plot', 'plot']
#   Positive Score: 16
#   Negative Score: 9
#   Polarity Score: 0.27999998880000043
#   Subjectivity Score: 0.04488330333055062
#
# Document 144:
#   Positive Words: ['richer', 'leading', 'lead', 'lead', 'lead', 'refresh', 'lead', 'sublime', 'reliable', 'rapid', 'advantages', 'progress', 'powerful', 'free', 'refresh', 'refresh', 'refresh', 'refresh', 'proper', 'refresh', 'lead', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'regression', 'cloud', 'regression', 'missed', 'cloud', 'inactive', 'issue', 'plot', 'issues', 'expired', 'inactive', 'issues', 'missed', 'error', 'issue', 'issue', 'plot']
#   Positive Score: 24
#   Negative Score: 18
#   Polarity Score: 0.1428571394557824
#   Subjectivity Score: 0.050663449878572436
#
# Document 145:
#   Positive Words: ['richer', 'leading', 'survivor', 'patient', 'patient', 'correct', 'ready', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue', 'died', 'died', 'death', 'death', 'manipulation', 'died']
#   Positive Score: 10
#   Negative Score: 7
#   Polarity Score: 0.17647057785467188
#   Subjectivity Score: 0.08457711400707904
#
# Document 146:
#   Positive Words: ['richer', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 4
#   Negative Score: 1
#   Polarity Score: 0.599999880000024
#   Subjectivity Score: 0.03906249969482422
#
# Document 147:
#   Positive Words: ['richer', 'leading', 'intelligence', 'innovation', 'extraordinary']
#   Negative Words: ['fatigue']
#   Positive Score: 5
#   Negative Score: 1
#   Polarity Score: 0.6666665555555741
#   Subjectivity Score: 0.03571428550170068

# %%
import os
import re
from nltk.corpus import stopwords

# Directories
text_dir = "C:/Users/Nidhi Dhameliya/Desktop/jupyter/Data_Extraction_and_Text_Analysis_for_Blackcoffer_company/TitleText"

stopwords = set(stopwords.words('english'))

def measure(file):
    try:
        # Try opening the file with utf-8 encoding
        with open(os.path.join(text_dir, file), 'r', encoding='utf-8') as f:
            text = f.read()
        
        # Remove punctuations
        text = re.sub(r'[^\w\s.]', '', text)
        
        # Split the text into sentences
        sentences = text.split('.')
        num_sentences = len(sentences)
        
        # Get total words in the file, excluding stopwords
        words = [word for word in text.split() if word.lower() not in stopwords]
        num_words = len(words)
        
        # Identify complex words (words with more than 2 syllables)
        complex_words = []
        for word in words:
            vowels = 'aeiou'
            syllable_count_word = sum(1 for letter in word if letter.lower() in vowels)
            if syllable_count_word > 2:
                complex_words.append(word)
        
        # Syllable count per word
        syllable_count = 0
        syllable_words = []
        for word in words:
            if word.endswith('es'):
                word = word[:-2]
            elif word.endswith('ed'):
                word = word[:-2]
            syllable_count_word = sum(1 for letter in word if letter.lower() in vowels)
            if syllable_count_word >= 1:
                syllable_words.append(word)
                syllable_count += syllable_count_word
        
        # Calculating metrics
        avg_sentence_len = num_words / num_sentences if num_sentences > 0 else 0
        avg_syllable_word_count = syllable_count / len(syllable_words) if syllable_words else 0
        percent_complex_words = len(complex_words) / num_words if num_words > 0 else 0
        fog_index = 0.4 * (avg_sentence_len + percent_complex_words)
        
        return avg_sentence_len, percent_complex_words, fog_index, len(complex_words), avg_syllable_word_count
    
    except Exception as e:
        print(f"Error reading file {file}: {e}")
        return 0, 0, 0, 0, 0

# Lists to store metrics
avg_sentence_length = []
percentage_of_complex_words = []
fog_index = []
complex_word_count = []
avg_syllable_word_count = []

# Iterate through each file in the directory
for file in os.listdir(text_dir):
    x, y, z, a, b = measure(file)
    avg_sentence_length.append(x)
    percentage_of_complex_words.append(y)
    fog_index.append(z)
    complex_word_count.append(a)
    avg_syllable_word_count.append(b)

# %%
import os
import re
from nltk.corpus import stopwords

# Directories
text_dir = "C:/Users/Nidhi Dhameliya/Desktop/jupyter/Data_Extraction_and_Text_Analysis_for_Blackcoffer_company/TitleText"
stopwords = set(stopwords.words('english'))

# Function to clean the text, remove stopwords and calculate word count & average word length
def cleaned_words(file):
    try:
        # Open file with 'utf-8' encoding to handle special characters
        with open(os.path.join(text_dir, file), 'r', encoding='utf-8') as f:
            text = f.read()
            # Remove punctuation
            text = re.sub(r'[^\w\s]', '', text)
            # Remove stopwords and split text into words
            words = [word for word in text.split() if word.lower() not in stopwords]
            # Calculate total length of words
            length = sum(len(word) for word in words)
            # Calculate average word length
            average_word_length = length / len(words) if len(words) > 0 else 0
        return len(words), average_word_length
    except Exception as e:
        print(f"Error reading file {file}: {e}")
        return 0, 0

# Lists to store results
word_count = []
average_word_length = []

# Iterate through each file in the directory
for file in os.listdir(text_dir):
    x, y = cleaned_words(file)
    word_count.append(x)
    average_word_length.append(y)

# Function to count personal pronouns in the text
def count_personal_pronouns(file):
    try:
        # Open file with 'utf-8' encoding to handle special characters
        with open(os.path.join(text_dir, file), 'r', encoding='utf-8') as f:
            text = f.read()
            # Define personal pronouns
            personal_pronouns = ["I", "we", "my", "ours", "us"]
            count = 0
            # Count occurrences of each pronoun
            for pronoun in personal_pronouns:
                count += len(re.findall(r"\b" + pronoun + r"\b", text))  # \b ensures whole word match
        return count
    except Exception as e:
        print(f"Error reading file {file}: {e}")
        return 0

# List to store personal pronouns count
pp_count = []

# Iterate through each file in the directory
for file in os.listdir(text_dir):
    x = count_personal_pronouns(file)
    pp_count.append(x)

# %%
import pandas as pd
import numpy as np

# Load the output dataframe
output_df = pd.read_excel('Output Data Structure.xlsx')

# Drop rows where URL_IDs 44, 57, and 144 do not exist
output_df.drop([44-37, 57-37, 144-37], axis=0, inplace=True)

# Define your variables (ensure these are already populated with data)
variables = [positive_score,
            negative_score,
            polarity_score,
            subjectivity_score,
            avg_sentence_length,
            percentage_of_complex_words,
            fog_index,
            avg_sentence_length,
            complex_word_count,
            word_count,
            avg_syllable_word_count,
            pp_count,
            average_word_length]

# Check the length of the dataframe and each variable
num_rows = len(output_df)  # Number of rows in the dataframe

for i, var in enumerate(variables):
    # Convert the variable to float and replace None with NaN
    var = [float(x) if x is not None else np.nan for x in var]
    
    # Ensure all variables match the number of rows in the dataframe
    if len(var) == num_rows:
        output_df.iloc[:, i + 2] = var
    elif len(var) < num_rows:
        # Pad with NaN if the variable is shorter
        var.extend([np.nan] * (num_rows - len(var)))
        output_df.iloc[:, i + 2] = var
    else:
        # Truncate if the variable is longer
        output_df.iloc[:, i + 2] = var[:num_rows]

# Save the dataframe to a CSV file
output_df.to_csv('Output_Data.csv', index=False)
